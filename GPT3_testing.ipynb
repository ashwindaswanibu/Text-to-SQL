# %%
import pandas as pd

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.0 MB/s eta 0:00:00
# ...

# %%
# !pip install openai==0.28

# %%
df = pd.read_json('/content/tables.json')

# %%
df
# Out:
#                                           column_names  \
# 0    [[-1, *], [0, perpetrator id], [0, people id],...
# 1    [[-1, *], [0, building], [0, room number], [0,...
# 2    [[-1, *], [0, id], [0, city], [0, country], [0...
# 3    [[-1, *], [0, institution id], [0, name], [0, ...
# 4    [[-1, *], [0, body builder id], [0, people id]...
# ..                                                 ...
# 161  [[-1, *], [0, employee ssn], [0, project numbe...
# 162  [[-1, *], [0, workshop id], [0, date], [0, ven...
# 163  [[-1, *], [0, item id], [0, title], [1, a id],...
# 164  [[-1, *], [0, party id], [0, party theme], [0,...
# 165  [[-1, *], [0, attribute id], [0, attribute nam...
#
#                                  column_names_original  \
# 0    [[-1, *], [0, Perpetrator_ID], [0, People_ID],...
# 1    [[-1, *], [0, building], [0, room_number], [0,...
# 2    [[-1, *], [0, id], [0, City], [0, Country], [0...
# 3    [[-1, *], [0, instID], [0, name], [0, country]...
# ...

# %%
df[df['db_id']=='flight_company']
# Out:
#                                         column_names  \
# 2  [[-1, *], [0, id], [0, city], [0, country], [0...
#
#                                column_names_original  \
# 2  [[-1, *], [0, id], [0, City], [0, Country], [0...
#
#                                         column_types           db_id  \
# 2  [text, number, text, text, text, text, text, n...  flight_company
#
#          foreign_keys primary_keys                         table_names  \
# 2  [[20, 7], [19, 1]]   [1, 7, 13]  [airport, operate company, flight]
#
#                  table_names_original
# 2  [airport, operate_company, flight]

# %%
import json
with open('/content/tables.json', 'r') as file:
    tables = json.load(file)

# %%
for example in data['validation']:
  #schema_info = df[df['db_id']==example['db_id']]['column_names']
  schema_info = next((item for item in tables if item.get('db_id') == example['db_id']), None)
  print(str(schema_info))
  break
# Out:
# {'column_names': [[-1, '*'], [0, 'stadium id'], [0, 'location'], [0, 'name'], [0, 'capacity'], [0, 'highest'], [0, 'lowest'], [0, 'average'], [1, 'singer id'], [1, 'name'], [1, 'country'], [1, 'song name'], [1, 'song release year'], [1, 'age'], [1, 'is male'], [2, 'concert id'], [2, 'concert name'], [2, 'theme'], [2, 'stadium id'], [2, 'year'], [3, 'concert id'], [3, 'singer id']], 'column_names_original': [[-1, '*'], [0, 'Stadium_ID'], [0, 'Location'], [0, 'Name'], [0, 'Capacity'], [0, 'Highest'], [0, 'Lowest'], [0, 'Average'], [1, 'Singer_ID'], [1, 'Name'], [1, 'Country'], [1, 'Song_Name'], [1, 'Song_release_year'], [1, 'Age'], [1, 'Is_male'], [2, 'concert_ID'], [2, 'concert_Name'], [2, 'Theme'], [2, 'Stadium_ID'], [2, 'Year'], [3, 'concert_ID'], [3, 'Singer_ID']], 'column_types': ['text', 'number', 'text', 'text', 'number', 'number', 'number', 'number', 'number', 'text', 'text', 'text', 'text', 'number', 'others', 'number', 'text', 'text', 'text', 'text', 'number', 'text'], 'db_id
# ...

# %%
import openai
from datasets import load_dataset
import sqlparse

# Replace with your actual OpenAI API key
api_key = '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'

# Initialize the OpenAI API client
openai.api_key = api_key

# Load the Spider dataset
data = load_dataset("spider")

em_count = 0
count = 0
# Iterate through the dataset
for example in data['validation']:  # You can use 'train' or 'test' as well
    count+=1
    if count>200:
      break
    question = example['question']
    ground_truth_query = example['query']
    schema_info = next((item for item in tables if item.get('db_id') == example['db_id']), None)
    keys = ['column_names_original', 'table_names_original', 'db_id']

    for key in keys:
        schema_info.pop(key, None)

    # Generate SQL query using the OpenAI GPT API
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt= "Write an sql code for this query: " + question + "Here's the schema information for the database: " + str(schema_info),
        max_tokens=50,
        api_key=api_key
    )
    print("Write an sql code for this query: " + question + " \nHere's the schema information for the database: " + str(schema_info))
    generated_query = response.choices[0].text.strip()


    # Check EM (Exact Match)
    if generated_query.lower() == ground_truth_query.lower():
        em_count += 1
    # else:
    #print("GENERATED",generated_query)
    #print("ACTUAL   ", ground_truth_query)
    #print("===============")

# Calculate EM percentage
total_examples = len(data['validation'])  # You can use 'train' or 'test' as well
em_percentage = (em_count / count) * 100

print(f"Exact Match (EM) Percentage: {em_percentage}%")
# Out:
# Exact Match (EM) Percentage: 67.3%
